# %% [markdown]
# ### **Функциональные требования веб-приложения:**
#
# #### **1. Функциональные требования Словарь**
#
# <table>
# <colgroup>
# <col style="width: 45%" />
# <col style="width: 54%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><strong>Словарь.Поиск:</strong></th>
# <th><strong>Поиск слов в словаре</strong></th>
# </tr>
# <tr class="odd">
# <th>.Найти:</th>
# <th>Веб-приложение должно предоставлять возможность поиска по
# словарям.</th>
# </tr>
# <tr class="header">
# <th>.Ошибка:</th>
# <th>Веб-приложение должно отображать сообщение о том, что слово не
# найдено в словаре и предлагать правильный вариант написания слова.</th>
# </tr>
# <tr class="odd">
# <th>.Просмотреть:</th>
# <th>Веб-приложение должно отображать перевод слова.</th>
# </tr>
# <tr class="header">
# <th>.Прослушать:</th>
# <th>Веб-приложение должно предоставлять возможность прослушать озвучку
# произношения слова.</th>
# </tr>
# <tr class="odd">
# <th>.НетОзвучки:</th>
# <th>Веб-приложение должно отображать уведомление о том, что для слова
# недоступна озвучка.</th>
# </tr>
# <tr class="header">
# <th>.Подробно:</th>
# <th><p>Веб-приложение должно предоставлять возможность просматривать
# иллюстрацию для слова.</p>
# <p>Веб-приложение должно предоставлять возможность просматривать
# варианты перевода слова в разных частях речи.</p></th>
# </tr>
# <tr class="odd">
# <th>.Добавить:</th>
# <th>Веб-приложение должно предоставлять возможность добавления слова в
# словарь пользователя.</th>
# </tr>
# <tr class="header">
# <th>.УжеДобавлено:</th>
# <th>Веб-приложение должно информировать о том, что слово было ранее
# добавлено в словарь пользователя.</th>
# </tr>
# <tr class="odd">
# <th><strong>Словарь.СловарьПользователя:</strong></th>
# <th><strong>Работать со словарём пользователя</strong></th>
# </tr>
# <tr class="header">
# <th>.Просмотреть:</th>
# <th>Веб-приложение должно отображать список слов с переводами.</th>
# </tr>
# <tr class="odd">
# <th>.Удалить:</th>
# <th>Веб-приложение должно предоставлять возможность удалить слово из
# словаря пользователя.</th>
# </tr>
# <tr class="header">
# <th>.Учить:</th>
# <th>Веб-приложение должно предоставлять возможность выбирать слова для
# изучения с помощью карточек.</th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# #### **2. Функциональные требования Карточки**
#
# <table>
# <colgroup>
# <col style="width: 45%" />
# <col style="width: 54%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><strong>Карточки.Словарь Пользователя:</strong></th>
# <th><strong>Работать с карточками в словаре пользователя</strong></th>
# </tr>
# <tr class="odd">
# <th>.Добавить:</th>
# <th>Веб-приложение должно предоставлять возможность добавления карточки
# в словарь пользователя.</th>
# </tr>
# <tr class="header">
# <th>.Удалить:</th>
# <th>Веб-приложение должно предоставлять возможность удалить карточку из
# словаря пользователя.</th>
# </tr>
# <tr class="odd">
# <th>.ПроверитьЗнания:</th>
# <th><p>Веб-приложение должно предоставлять возможность пользователю
# открыть выбранную карточку со словом после его авторизации в
# приложении.</p>
# <p>Веб-приложение должно показывать перевод слова.</p>
# <p>Веб-приложение должно учитывать результат выбора действия
# пользователя “Помню” или “Не помню”.</p>
# <p>Веб-приложение должно показывать следующее слово после выбора
# пользователем действия “Помню”</p>
# <p>Веб-приложение должно оставлять пользователя в текущей карточке после
# выбора пользователем действия “Не помню”.</p></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# ####
#
# #### **3. Функциональные требования Видео**
#
# | **Видео.Словарь:** | **Смотреть видео со словом в словаре веб-приложения**                                         |
# |---------------------------------|---------------------------------------|
# | .Просмотреть:      | Веб-приложение должно предоставлять возможность просматривать видео.                          |
# | .НетВидео:         | Веб-приложение должно отображать уведомление о том, что для слова недоступно видео.           |
# | .НетЗвука:         | Веб-приложение должно отображать уведомление о том, что для слова недоступно видео со звуком. |
# | .Ошибка:           | Веб-приложение должно отображать уведомление о технической ошибке для перезагрузки видео.     |
# | .Пауза:            | Веб-приложение должно предоставлять возможность ставить видео на паузу.                       |
# | .ПеремотатьВперед: | Веб-приложение должно предоставлять возможность перемотки видео вперед                        |
# | .ПеремотатьНазад:  | Веб-приложение должно предоставлять возможность перемотки видео назад                         |
# | .Субтитры:         | Веб-приложение должно предоставлять возможность отображать субтитры                           |
#
# ####
